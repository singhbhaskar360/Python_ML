# %% [markdown]
# <a href="https://colab.research.google.com/github/singhbhaskar360/Python_ML/blob/main/Seaborn_task_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %% [markdown]
# ###`Q 1-3` Using the 'diamonds' dataset - sns.load_dataset('diamonds')
# 1. Create a violinplot of 'price' grouped by 'cut'.
# 2. Create regplot on `carat` vs `price`. and give hue on 'cut'
# 3. Create boxplot on 'color' and 'price'

# %%
# code here
diamond=sns.load_dataset('diamonds')

# %%
diamond.head(1)
# Out:
#    carat    cut color clarity  depth  table  price     x     y     z
# 0   0.23  Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43

# %%
#1
sns.catplot(data=diamond,x='cut',y='price',kind='violin')

# %%
#2
sns.lmplot(data=diamond,x='carat',y='price',hue='cut')

# %%
sns.catplot(data=diamond,x='color',y='price',kind='box')

# %% [markdown]
# ###`Q 4` Using the 'Taxis' dataset - sns.load_dataset('taxis')
# 4.1. Create a categorical estimate plot of the totl fare - 'total' for each payment type - 'payment'.
#
# 4.2. Create a regression plot on time of ride  vs total fare. You will need to calculate ride time using pickup and dropoff column.
#
# 4.3 Give hue on payment type. and Another plot hue on taxi 'color'. Observe the plot.

# %%
# code here
#4.1
taxis=sns.load_dataset('taxis')

# %%
taxis.head(1)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1       1.6   7.0  2.15
#
#    tolls  total   color      payment      pickup_zone         dropoff_zone  \
# 0    0.0  12.95  yellow  credit card  Lenox Hill West  UN/Turtle Bay South
#
#   pickup_borough dropoff_borough
# 0      Manhattan       Manhattan

# %%
#4.1
sns.catplot(data=taxis,x='payment',y='total',kind='bar',hue='color')

# %%
sns.catplot(data=taxis,x='payment',y='total',kind='point')

# %%
taxis.head(1)
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1       1.6   7.0  2.15
#
#    tolls  total   color      payment      pickup_zone         dropoff_zone  \
# 0    0.0  12.95  yellow  credit card  Lenox Hill West  UN/Turtle Bay South
#
#   pickup_borough dropoff_borough      time_travel
# 0      Manhattan       Manhattan  0 days 00:06:15

# %% [markdown]
# ## Problem 5-12:
#
# ### **`Problem 5:`** Draw a strip plot and swarm plot between "gender" and "bloodpressure" w.r.t "smoker" (use as hue parameter). Also add title to the charts.

# %%
# code here
ins=pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQVpcVtdYdZU4zU4-lqxt-iPHkyndDWs_aqEDUu9ZodlJ48Dku0PFgdXlj2N5RCmwXJrNtZLsI_wEVf/pub?gid=220677750&single=true&output=csv')

# %%
ins.head(1)
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87

# %%
#5.1
sns.catplot(data=ins,x='gender',y='bloodpressure',kind='strip',hue='smoker')

# %%
#5.2
sns.catplot(data=ins,x='gender',y='bloodpressure',kind='swarm',hue='smoker')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 12.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 11.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### **`Problem 6:`** Draw a Box-plot and a Violin plot of which x-axis represents the "region" and the y-axis represents the "bmi". Also add extra information of the column "diabetic".

# %%
# code here
#6
sns.catplot(data=ins,x='region',y='bmi',kind='box',hue='diabetic')

# %% [markdown]
# ### **`Problem  7:`** Draw a bar plot and point plot of which x-axis represents the "gender" and y-axis represents "claim". Also add extra information about "smoker" column.

# %%
# code here
#7
sns.catplot(data=ins,x='gender',y='claim',kind='bar',hue='smoker')

# %%
sns.catplot(data=ins,x='gender',y='claim',kind='point',hue='smoker')

# %% [markdown]
# ### **`Problem 8:`** Draw a reg plot between "age" and "bmi" columns.

# %%
# code here
sns.regplot(data=ins,x='age',y='bmi')
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %% [markdown]
# ### **`Problem 9:`** Draw a pair plot of the insurance data. Use "gender" as hue parameter.

# %%
# code here
sns.pairplot(data=ins,hue='gender')

# %% [markdown]
# ### **`Problem 10:`** Draw a pair grid of the insurance data and use "diabetic" column as a hue parameter. Also, make the diagonal plots as box-plot, upper parts as scatter plot and the lower parts as kde plot.

# %%
# code here

# %% [markdown]
# ### **`Prolem 11:`** Draw a joint plot as scatter between "bloodpressure" and "bmi". Use "smoker" as hue parameter.

# %%
# code here

# %% [markdown]
# ### **`Problem 12:`** Draw a joint grid of which x-axis represents "age" and y-axis represents "claim". Draw

# %%
# code here
